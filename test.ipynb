# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
shapefile_path = "Regiones/Regional.shp"
gdf = gpd.read_file(shapefile_path)

# %%
# filtrar elementos solo para 'Región del Bío-Bío'

gdf_bb = gdf[gdf['Region'] == 'Región del Bío-Bío']
gdf_bb.plot()
# Out:
# <Axes: >

# %%
# leer archivos .nc

import xarray as xr
ds = xr.open_dataset('pr/CR2MET_pr_v2.5_day_2019_01_005deg.nc')

#graficar precipitaciones en la mascara de chile para el 1 de enero de 2019

ds.pr[0].where(ds.cl_mask == 1).plot()
